# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/ShrinilamangaiR/Downloads/Contact_Lenses.csv')

# %%
df
# Out:
#      Unnamed: 0      id                                          image_url  \
# 0             0  118538  https://static5.lenskart.com/media/catalog/pro...
# 1             1  123656  https://static5.lenskart.com/media/catalog/pro...
# 2             2  149532  https://static5.lenskart.com/media/catalog/pro...
# 3             3   38723  https://static5.lenskart.com/media/catalog/pro...
# 4             4  133855  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 938         938  149509  https://static5.lenskart.com/media/catalog/pro...
# 939         939  148368  https://static5.lenskart.com/media/catalog/pro...
# 940         940  145628  https://static5.lenskart.com/media/catalog/pro...
# 941         941  144898  https://static5.lenskart.com/media/catalog/pro...
# 942         942  144897  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 943 non-null    int64
#  1   id                         943 non-null    int64
#  2   image_url                  943 non-null    object
#  3   image_url_suffix           943 non-null    object
#  4   imageUrls                  943 non-null    object
#  5   product_url                943 non-null    object
#  6   occasion                   61 non-null     object
#  7   suited_for                 1 non-null      object
#  8   brand_name                 943 non-null    object
#  9   brand_name_en              943 non-null    object
#  10  model_name                 943 non-null    object
#  11  prices                     943 non-null    object
#  12  is_tbyb                    943 non-null    bool
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0             id  totalColorAvailable  wishlistCount  \
# count  943.000000     943.000000                943.0     943.000000
# mean   471.000000  165227.079533                  0.0     796.447508
# std    272.364951   35321.687496                  0.0    2323.735580
# min      0.000000    7555.000000                  0.0       0.000000
# 25%    235.500000  145632.500000                  0.0       0.000000
# 50%    471.000000  151340.000000                  0.0       0.000000
# 75%    706.500000  201664.000000                  0.0     486.500000
# max    942.000000  218842.000000                  0.0   28175.000000
#
#        purchaseCount   avgRating  totalNoOfRatings  arModelMsiteAndDesktopUrl  \
# count   9.430000e+02  943.000000        567.000000                        0.0
# mean    3.058000e+04    2.769777         43.640212                        NaN
# std     2.877393e+05    2.277222        129.729404                        NaN
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0                   943
# id                           943
# image_url                    909
# image_url_suffix             909
# imageUrls                      1
# product_url                  943
# occasion                       5
# suited_for                     1
# brand_name                    33
# brand_name_en                 33
# model_name                   680
# prices                        94
# is_tbyb                        1
# tags                          41
# color_options                  1
# totalColorAvailable            1
# is_ditto                       2
# classification                 6
# specifications                39
# wishlistCount                369
# purchaseCount                847
# avgRating                     28
# totalNoOfRatings             116
# hashtagList                   68
# offerName                      6
# clUsage                       10
# arModelAndroidUrl            509
# arModelIOSUrl                546
# ...

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df
# Out:
#      Unnamed: 0      id                                          image_url  \
# 0             0  118538  https://static5.lenskart.com/media/catalog/pro...
# 1             1  123656  https://static5.lenskart.com/media/catalog/pro...
# 2             2  149532  https://static5.lenskart.com/media/catalog/pro...
# 3             3   38723  https://static5.lenskart.com/media/catalog/pro...
# 4             4  133855  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 938         938  149509  https://static5.lenskart.com/media/catalog/pro...
# 939         939  148368  https://static5.lenskart.com/media/catalog/pro...
# 940         940  145628  https://static5.lenskart.com/media/catalog/pro...
# 941         941  144898  https://static5.lenskart.com/media/catalog/pro...
# 942         942  144897  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# ...

# %%
df.shape
# Out:
# (943, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            943 non-null    int64
#  1   id                    943 non-null    int64
#  2   image_url             943 non-null    object
#  3   image_url_suffix      943 non-null    object
#  4   imageUrls             943 non-null    object
#  5   product_url           943 non-null    object
#  6   occasion              61 non-null     object
#  7   suited_for            1 non-null      object
#  8   brand_name            943 non-null    object
#  9   brand_name_en         943 non-null    object
#  10  model_name            943 non-null    object
#  11  prices                943 non-null    object
#  12  is_tbyb               943 non-null    bool
#  13  tags                  668 non-null    object
#  14  color_options         943 non-null    object
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0              943
# id                      943
# image_url               909
# image_url_suffix        909
# imageUrls                 1
# product_url             943
# occasion                  5
# suited_for                1
# brand_name               33
# brand_name_en            33
# model_name              680
# prices                   94
# is_tbyb                   1
# tags                     41
# color_options             1
# totalColorAvailable       1
# is_ditto                  2
# classification            6
# specifications           39
# wishlistCount           369
# purchaseCount           847
# avgRating                28
# totalNoOfRatings        116
# hashtagList              68
# offerName                 6
# clUsage                  10
# arModelAndroidUrl       509
# arModelIOSUrl           546
# arModelOriginalUrl      581
# qty                     555
# subCollection            52
# relatedItems              1
# isCygnusEnabled           2
# ...

# %%
df[df['suited_for'].notnull()]
# Out:
#     Unnamed: 0      id                                          image_url  \
# 61          61  209630  https://static5.lenskart.com/media/catalog/pro...
#
#                                      image_url_suffix imageUrls  \
# 61  /h/i/grey-black-full-rim-square-kids-5-8-yrs-h...        []
#
#                                           product_url occasion suited_for  \
# 61  https://www.lenskart.com/hooper-hp-s15816m-c1-...      NaN   8-12 yrs
#
#    brand_name brand_name_en  ...  color      size   width  \
# 61     Hooper        Hooper  ...  Black  8-12 yrs  125 mm
#
#                      cmsLinkAndroid                       cmsLinkIos  \
# 61  https://www.lenskart.com/page-3  https://www.lenskart.com/page-3
#
#                                       frameColorImage  subCollectionId  \
# 61  https://ds-static.lenskart.com/product_color_b...              NaN
#
#    isCombo tryOnImageUrl  offer_image
# 61     NaN           NaN          NaN
#
# [1 rows x 47 columns]

# %%
 df[df['isCombo'].notnull()]
# Out:
#      Unnamed: 0      id                                          image_url  \
# 499         499  218803  https://static5.lenskart.com/media/catalog/pro...
# 501         501  218802  https://static5.lenskart.com/media/catalog/pro...
# 503         503  218801  https://static5.lenskart.com/media/catalog/pro...
# 505         505  218807  https://static5.lenskart.com/media/catalog/pro...
# 507         507  218806  https://static5.lenskart.com/media/catalog/pro...
# 509         509  218805  https://static5.lenskart.com/media/catalog/pro...
# 511         511  218804  https://static5.lenskart.com/media/catalog/pro...
# 513         513  218811  https://static5.lenskart.com/media/catalog/pro...
# 515         515  218809  https://static5.lenskart.com/media/catalog/pro...
# 517         517  218808  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# 499  /no-resize/a/i/aquacolor-combo-walnut-brown-mi...        []
# ...

# %%
 df[df['tryOnImageUrl'].notnull()]
# Out:
#      Unnamed: 0      id                                          image_url  \
# 645         645  200122  https://static5.lenskart.com/media/catalog/pro...
# 846         846  144908  https://static5.lenskart.com/media/catalog/pro...
# 852         852  144902  https://static5.lenskart.com/media/catalog/pro...
# 888         888  137699  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# 645  /no-resize/a/i/aquacolor-tricky-turquoise-powe...        []
# 846  /no-resize/a/i/aquacolor-cosmo-violet-zero-pow...        []
# 852  /no-resize/a/i/aquacolor-emerald-blue-zero-pow...        []
# 888  /no-resize/a/i/aquacolor-amazing-olive-zero-po...        []
#
#                                            product_url occasion suited_for  \
# 645  https://www.lenskart.com/aquacolor-tricky-turq...      NaN        NaN
# 846  https://www.lenskart.com/aqua-color-cosmo-viol...      NaN        NaN
# ...

# %%
 df[df['offer_image'].notnull()]
# Out:
#      Unnamed: 0      id                                          image_url  \
# 888         888  137699  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# 888  /no-resize/a/i/aquacolor-amazing-olive-zero-po...        []
#
#                                            product_url occasion suited_for  \
# 888  https://www.lenskart.com/aqua-color-amazing-ol...      NaN        NaN
#
#     brand_name brand_name_en  ... color size  width cmsLinkAndroid cmsLinkIos  \
# 888  Aquacolor     Aquacolor  ...   NaN  NaN    NaN            NaN        NaN
#
#      frameColorImage  subCollectionId isCombo  \
# 888              NaN              NaN     NaN
#
#                                          tryOnImageUrl  \
# 888  https://static.aqualens.in/IN/B2C_APP/variants...
#
#                                            offer_image
# 888  https://static.lenskart.com/media/wysiwyg/blan...
#
# [1 rows x 47 columns]

# %%
 df[df['occasion'].notnull()]
# Out:
#      Unnamed: 0      id                                          image_url  \
# 77           77  206261  https://static5.lenskart.com/media/catalog/pro...
# 82           82  205990  https://static5.lenskart.com/media/catalog/pro...
# 84           84  205989  https://static5.lenskart.com/media/catalog/pro...
# 86           86  205987  https://static5.lenskart.com/media/catalog/pro...
# 90           90  209084  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 708         708  152844  https://static5.lenskart.com/media/catalog/pro...
# 709         709  152830  https://static5.lenskart.com/media/catalog/pro...
# 877         877  144856  https://static5.lenskart.com/media/catalog/pro...
# 894         894  134222  https://static5.lenskart.com/media/catalog/pro...
# 895         895  141248  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# ...

# %%
columns_to_drop = ['offer_image', 'tryOnImageUrl', 'suited_for','cmsLinkIos','cmsLinkAndroid']

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#      Unnamed: 0      id                                          image_url  \
# 0             0  118538  https://static5.lenskart.com/media/catalog/pro...
# 1             1  123656  https://static5.lenskart.com/media/catalog/pro...
# 2             2  149532  https://static5.lenskart.com/media/catalog/pro...
# 3             3   38723  https://static5.lenskart.com/media/catalog/pro...
# 4             4  133855  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 938         938  149509  https://static5.lenskart.com/media/catalog/pro...
# 939         939  148368  https://static5.lenskart.com/media/catalog/pro...
# 940         940  145628  https://static5.lenskart.com/media/catalog/pro...
# 941         941  144898  https://static5.lenskart.com/media/catalog/pro...
# 942         942  144897  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix imageUrls  \
# ...

# %%
df.shape
# Out:
# (943, 42)

# %%
empty_list_columns = [col for col in df.columns if all(val == '[]' for val in df[col])]
empty_list_columns
# Out:
# ['imageUrls', 'color_options', 'relatedItems', 'prescriptionType']

# %%
df.drop(columns=empty_list_columns, inplace=True)

# %%
df.shape
# Out:
# (943, 38)

# %%
df
# Out:
#      Unnamed: 0      id                                          image_url  \
# 0             0  118538  https://static5.lenskart.com/media/catalog/pro...
# 1             1  123656  https://static5.lenskart.com/media/catalog/pro...
# 2             2  149532  https://static5.lenskart.com/media/catalog/pro...
# 3             3   38723  https://static5.lenskart.com/media/catalog/pro...
# 4             4  133855  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 938         938  149509  https://static5.lenskart.com/media/catalog/pro...
# 939         939  148368  https://static5.lenskart.com/media/catalog/pro...
# 940         940  145628  https://static5.lenskart.com/media/catalog/pro...
# 941         941  144898  https://static5.lenskart.com/media/catalog/pro...
# 942         942  144897  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix  \
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0              943
# id                      943
# image_url               909
# image_url_suffix        909
# product_url             943
# occasion                  5
# brand_name               33
# brand_name_en            33
# model_name              680
# prices                   94
# is_tbyb                   1
# tags                     41
# totalColorAvailable       1
# is_ditto                  2
# classification            6
# specifications           39
# wishlistCount           369
# purchaseCount           847
# avgRating                28
# totalNoOfRatings        116
# hashtagList              68
# offerName                 6
# clUsage                  10
# arModelAndroidUrl       509
# arModelIOSUrl           546
# arModelOriginalUrl      581
# qty                     555
# subCollection            52
# isCygnusEnabled           2
# isCashbackApplicable      1
# searchProductName       566
# brand_logo                4
# color                    41
# ...

# %%
df['clUsage']
# Out:
# 0      Continuous Usage: 24 Hrs
# 1                           NaN
# 2                           NaN
# 3      Continuous Usage: 10 Hrs
# 4                           NaN
#                  ...
# 938                         NaN
# 939                         NaN
# 940                 Accessories
# 941    Continuous Usage: 10 Hrs
# 942    Continuous Usage: 10 Hrs
# Name: clUsage, Length: 943, dtype: object

# %%
df.fillna('Null', inplace=True)

# %%
df
# Out:
#      Unnamed: 0      id                                          image_url  \
# 0             0  118538  https://static5.lenskart.com/media/catalog/pro...
# 1             1  123656  https://static5.lenskart.com/media/catalog/pro...
# 2             2  149532  https://static5.lenskart.com/media/catalog/pro...
# 3             3   38723  https://static5.lenskart.com/media/catalog/pro...
# 4             4  133855  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 938         938  149509  https://static5.lenskart.com/media/catalog/pro...
# 939         939  148368  https://static5.lenskart.com/media/catalog/pro...
# 940         940  145628  https://static5.lenskart.com/media/catalog/pro...
# 941         941  144898  https://static5.lenskart.com/media/catalog/pro...
# 942         942  144897  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix  \
# ...

# %%
df.to_csv('Contact_Lenses_Cleaned.csv', index=False)

# %%
df1 = pd.read_csv('Contact_Lenses_Cleaned.csv')

# %%
df1
# Out:
#      Unnamed: 0      id                                          image_url  \
# 0             0  118538  https://static5.lenskart.com/media/catalog/pro...
# 1             1  123656  https://static5.lenskart.com/media/catalog/pro...
# 2             2  149532  https://static5.lenskart.com/media/catalog/pro...
# 3             3   38723  https://static5.lenskart.com/media/catalog/pro...
# 4             4  133855  https://static5.lenskart.com/media/catalog/pro...
# ..          ...     ...                                                ...
# 938         938  149509  https://static5.lenskart.com/media/catalog/pro...
# 939         939  148368  https://static5.lenskart.com/media/catalog/pro...
# 940         940  145628  https://static5.lenskart.com/media/catalog/pro...
# 941         941  144898  https://static5.lenskart.com/media/catalog/pro...
# 942         942  144897  https://static5.lenskart.com/media/catalog/pro...
#
#                                       image_url_suffix  \
# ...
