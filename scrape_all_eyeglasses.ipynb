# %%
import logging
import requests
import pandas
import json
# Out:
# C:\Users\AkhilanN\AppData\Local\Temp\ipykernel_14996\415664135.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas

# %%
logging.basicConfig(filename='logFile.log', encoding='utf-8', format='%(asctime)s - %(message)s', level=logging.INFO)
logging.info('Started')

# %%
session = requests.Session()

# %%
eyeglasses_base_url = 'https://api-gateway.juno.lenskart.com/v2/products/category/3363?page-size=1000'

# %%
#To scrape the product data from product page
def get_product_details(url:str):
    session = requests.Session()
    try:
        res = session.get(url)
        source_page_content = res.text
        start_pattern = '"productDetailData":'
        end_pattern = '"cmsData":{'
        start_index = source_page_content.find(start_pattern)
        end_index = source_page_content.find(end_pattern,  start_index)
        if start_index != -1 and end_index != -1:
            json_data_str = source_page_content[start_index + len(start_pattern):end_index].rstrip(',')
            return json_data_str
    except Exception as e:
        #print("Error getting product data", e)
        return None

# %%
def add_response_to_list(res, df_list):

    res_json = json.loads(res.text)
    products_list = res_json["result"]["product_list"]

    for product in products_list:
        product_dict = product

        # flatten prices
        for price_details in product["prices"]:
            product_dict[price_details["name"]] = price_details["price"]

        # flatten hashtags
        for hashtag_details in product["hashtagList"]:
            if("property" in hashtag_details):
                if("name" in hashtag_details):
                    product_dict[hashtag_details["property"]] = hashtag_details["name"]
                else:
                    product_dict[hashtag_details["property"]] = 'NULL'

        # go to product url and get its details
        product_details = get_product_details(product["product_url"])
        logging.info(f"get product details called for {product["id"]} with url {product["product_url"]}")
        
        if(product_details is not None):
            product_details_json = json.loads(get_product_details(product["product_url"]))

            product_dict["productName"] = product_details_json["productName"]
            # get each general product info in new col
            for product_info in product_details_json["generalProductInfo"]:
                product_dict[product_info["nameEn"]] = product_info["valueEn"]

        
        df_list.append(product_dict)

# %%
print(type(get_product_details('https://www.lenskart.com/hooper-hp-e10077-c2-eyeglasses.html')))
# Out:
# <class 'str'>

# %%
df_list = []

# %%
for page_no in range(5):
    url = eyeglasses_base_url + f'&page={page_no}'
    file_path = f'./pages/product_list_pages/page{page_no}.json'

    # make get request to url
    page_response = session.get(url)
    logging.info(f"Response status for {url}: {page_response.status_code}")
    
    # writ to html
    with open(file_path, 'wb') as curr_page_file:
        curr_page_file.write(page_response.content)

    logging.info(f"Response contents from {url} written to: {file_path}")

    add_response_to_list(page_response, df_list)

# %%
df_list
# Out:
# [{'id': '146012',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/transparent-gold-full-rim-rectangle-lenskart-air-essentials-la-e13517-c2-eyeglasses_csvfile-1695816787888-g_7549_0_image_pla.jpg',
#   'image_url_suffix': '/l/i/transparent-gold-full-rim-rectangle-lenskart-air-essentials-la-e13517-c2-eyeglasses_csvfile-1695816787888-g_7549_0_image_pla.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e13517-c2-eyeglasses.html',
#   'color': 'Transparent',
#   'size': 'Medium',
#   'width': '134 mm',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/air-logo-Hi.jpg',
#   'model_name': 'LA E13517',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Air Essentials',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 2904,
#   'purchaseCount': 77236,
#   'avgRating': 4.65,
#   'totalNoOfRatings': '146',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Rectangle', 'id': 11345, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/146012/android/sku_146012.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/146012/ios/sku_146012.scn',
#   'arModelMsiteAndDesktopUrl': '',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/146012/orignal/sku_146012.glb',
#   'qty': 5743,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/146012_bubble.png',
#   'subCollection': 'AIR ESSENTIALS',
#   'subCollectionId': 26802,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Transparent Full Rim Rectangle Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Rectangle',
#   'brandname_id': 'Lenskart Air',
#   'frametype_id': 'Full Rim',
#   'productName': 'Transparent Full Rim Rectangle',
#   'Model No.': 'LA E13517',
#   'Frame Size': 'Medium',
#   'Frame Width': '134 mm',
#   'Frame Dimensions': '54-16-148',
#   'Frame colour': 'Transparent',
#   'Weight': '17 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90 & Acetate',
#   'Frame Material': 'TR90',
#   'Temple Material': 'Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'Air Essentials',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '42 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Transparent Gold'},
#  {'id': '216521',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/lenskart-air-la-e15417-w-c1-eyeglasses_csvfile-1701688526805-img_7894.jpg',
#   'image_url_suffix': '/l/i/lenskart-air-la-e15417-w-c1-eyeglasses_csvfile-1701688526805-img_7894.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-hustlr-la-e15415-c1-eyeglasses.html',
#   'color': 'Ocean Blue',
#   'occasion': '',
#   'size': 'Medium',
#   'width': '139 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'brand_logo': '',
#   'model_name': 'LA E15417-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Ocean Blue',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 5230,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'LKBLUCE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': '',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/216521/android/sku_216521.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/216521/ios/sku_216521.scn',
#   'arModelMsiteAndDesktopUrl': '',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/216521/orignal/sku_216521.glb',
#   'qty': 2328,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/216521_bubble.png',
#   'subCollection': 'Lenskart Hustlr',
#   'subCollectionId': 26161,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Peyush Bansal Shark Tank Ocean Blue Full Rim Lenskart Hustlr Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Ocean Blue Full Rim Wayfarer',
#   'Model No.': 'LA E15417-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '50-21-150',
#   'Frame Dimensions With Height': '',
#   'Suited For': '',
#   'Frame colour': 'Ocean Blue',
#   'Glass Color': '',
#   'Weight': '16 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90',
#   'Frame Material': 'TR90',
#   'Temple Material': 'TR90',
#   'Prescription Type': '',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Light-Weight',
#   'Collection': 'Lenskart HUSTLR',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '42 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Ocean Blue',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '217261',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/lenskart-hustlr-lh-e16985-w-c5-eyeglasses_img_2263_18_jan24.jpg',
#   'image_url_suffix': '/l/i/lenskart-hustlr-lh-e16985-w-c5-eyeglasses_img_2263_18_jan24.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-hustlr-lh-e16985-w-c5-eyeglasses.html',
#   'color': 'Transparent',
#   'occasion': '',
#   'size': 'Medium',
#   'width': '139 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'model_name': 'LH E16985-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Hustlr ACE-Crystal',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': False,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 2679,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/217261/android/sku_217261.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/217261/ios/sku_217261.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/217261/orignal/sku_217261.glb',
#   'qty': 2161,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/217261_bubble.png',
#   'subCollection': 'Hustlr ACE',
#   'subCollectionId': 27732,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Lenskart Hustlr LH E16985-W C5 Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Crystal Full Rim Wayfarer',
#   'Model No.': 'LH E16985-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '50-20-145',
#   'Frame Dimensions With Height': '',
#   'Suited For': '',
#   'Frame colour': 'Crystal',
#   'Glass Color': '',
#   'Weight': '24 gm',
#   'Weight Group': 'Average',
#   'Material': 'Acetate',
#   'Frame Material': 'Acetate',
#   'Temple Material': 'Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Lenskart HUSTLR',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '43 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Crystal',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '216712',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/flamingo-full-rim-wayfarer-lenskart-air-hustlr-la-e15417-w-c3-eyeglasses_csvfile-1706513126187-img_7914.jpg',
#   'image_url_suffix': '/l/i/flamingo-full-rim-wayfarer-lenskart-air-hustlr-la-e15417-w-c3-eyeglasses_csvfile-1706513126187-img_7914.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-la-e15417-w-c7-eyeglasses.html',
#   'color': 'Pink',
#   'occasion': '',
#   'size': 'Medium',
#   'width': '139 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'brand_logo': '',
#   'model_name': 'LA E15417-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Flamingo',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 2954,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': '',
#   'cmsLinkIos': '',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/216712/android/sku_216712.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/216712/ios/sku_216712.scn',
#   'arModelMsiteAndDesktopUrl': '',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/216712/orignal/sku_216712.glb',
#   'qty': 1400,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/216712_bubble.png',
#   'subCollection': 'Lenskart Hustlr',
#   'subCollectionId': 26161,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Flamingo Full Rim Wayfarer Lenskart Air Hustlr LA E15417-W-C3 Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Flamingo Full Rim Wayfarer',
#   'Model No.': 'LA E15417-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '50-21-150',
#   'Frame Dimensions With Height': '',
#   'Suited For': '',
#   'Frame colour': 'Flamingo',
#   'Glass Color': '',
#   'Weight': '20 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90',
#   'Frame Material': 'TR90',
#   'Temple Material': 'TR90',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Light-Weight',
#   'Collection': 'Lenskart HUSTLR',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '42 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Flamingo',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '201333',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/lenskart-air-la-e13068-c6-eyeglasses_g_4836_03_03_2023.jpg',
#   'image_url_suffix': '/l/i/lenskart-air-la-e13068-c6-eyeglasses_g_4836_03_03_2023.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e13068-c6-eyeglasses.html',
#   'color': 'Grey',
#   'size': 'Medium',
#   'width': '134 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'model_name': 'LA E13068',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Air Fusion',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 26504,
#   'avgRating': 4.65,
#   'totalNoOfRatings': '166',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Square', 'id': 19404, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'qty': 950,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/201333_bubble.png',
#   'subCollection': 'Refresher_Apr23',
#   'subCollectionId': 26925,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Grey Transparent Full Rim Wayfarer Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Square',
#   'brandname_id': 'Lenskart Air',
#   'frametype_id': 'Full Rim',
#   'productName': 'Grey Transparent Full Rim Square',
#   'Model No.': 'LA E13068',
#   'Frame Size': 'Medium',
#   'Frame Width': '134 mm',
#   'Frame Dimensions': '52-17-145',
#   'Suited For': '',
#   'Frame colour': 'Grey Transparent',
#   'Weight': '12 mm',
#   'Weight Group': 'Light',
#   'Material': 'Ultem & Stainless Steel',
#   'Frame Material': 'Ultem',
#   'Temple Material': 'Stainless Steel',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Air Fusion',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '44 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Silver Transparent',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '201315',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/black-silver-full-rim-geometric-vincent-chase-sleek-steel-vc-e13634-c7-eyeglasses_g_4950_03_01_23.jpg',
#   'image_url_suffix': '/v/i/black-silver-full-rim-geometric-vincent-chase-sleek-steel-vc-e13634-c7-eyeglasses_g_4950_03_01_23.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-e13634-c7-eyeglasses.html',
#   'color': 'Silver Black',
#   'size': 'Medium',
#   'width': '134 mm',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/VC-H.jpg',
#   'model_name': 'VC E13634',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Sleek Steel',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 8629,
#   'avgRating': 4.75,
#   'totalNoOfRatings': '124',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Geometric', 'id': 24178, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/201315/android/sku_201315.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/201315/ios/sku_201315.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/201315/orignal/sku_201315.glb',
#   'qty': 3437,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/201315_bubble.png',
#   'subCollection': 'SLEEK STEEL',
#   'subCollectionId': 25036,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Black Silver Full Rim Geometric Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Geometric',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Black Silver Full Rim Geometric',
#   'Model No.': 'VC E13634',
#   'Frame Size': 'Medium',
#   'Frame Width': '134 mm',
#   'Frame Dimensions': '52-16-145',
#   'Frame colour': 'Black Silver',
#   'Glass Color': '',
#   'Weight': '22 gm',
#   'Weight Group': 'Average',
#   'Material': '',
#   'Frame Material': 'Stainless Steel',
#   'Temple Material': 'Stainless Steel',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'SLEEK STEEL',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '44 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Silver'},
#  {'id': '211383',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/blue-orange-full-rim-rectangle-lenskart-air-essentials-la-e16153-c3-eyeglasses_g_9603_18_08_2023.jpg',
#   'image_url_suffix': '/l/i/blue-orange-full-rim-rectangle-lenskart-air-essentials-la-e16153-c3-eyeglasses_g_9603_18_08_2023.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e16153-c-c3-eyeglasses.html',
#   'color': 'Blue',
#   'occasion': '',
#   'size': 'Medium',
#   'width': '135 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'model_name': 'LA E16153',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Blue Billion',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 2146,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Rectangle', 'id': 11345, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/211383/android/sku_211383.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/211383/ios/sku_211383.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/211383/orignal/sku_211383.glb',
#   'qty': 670,
#   'subCollection': 'BLUE BILLION',
#   'subCollectionId': 26601,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Blue Orange Full Rim Rectangle Lenskart Air Essentials LA E16153-C3 Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Rectangle',
#   'brandname_id': 'Lenskart Air',
#   'frametype_id': 'Full Rim',
#   'productName': 'Blue Full Rim Rectangle',
#   'Model No.': 'LA E16153',
#   'Frame Size': 'Medium',
#   'Frame Width': '135 mm',
#   'Frame Dimensions': '52-17-140',
#   'Suited For': '',
#   'Frame colour': 'Blue',
#   'Weight': '20 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90',
#   'Frame Material': 'TR90',
#   'Temple Material': 'TR90',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Air Essentials',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '39 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Blue Orange',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '147507',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/vincent-chase-vc-e13037-f-im-rect-way-ace-crl-ue-trt-c6-eyeg_g_0533.jpg',
#   'image_url_suffix': '/v/i/vincent-chase-vc-e13037-f-im-rect-way-ace-crl-ue-trt-c6-eyeg_g_0533.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-e13037-full-rim-rect-way-acetate-crystal-blue-transparent-c6-eyeglasses.html',
#   'color': 'Transparent',
#   'size': 'Medium',
#   'width': '136 mm',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/VC-H.jpg',
#   'model_name': 'VC E13037',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Classic Acetate',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 8886,
#   'purchaseCount': 62449,
#   'avgRating': 4.5,
#   'totalNoOfRatings': '480',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Rectangle', 'id': 11345, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/147507/android/sku_147507.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/147507/ios/sku_147507.scn',
#   'arModelMsiteAndDesktopUrl': '',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/147507/orignal/sku_147507.glb',
#   'qty': 10716,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/147507_bubble.png',
#   'subCollection': 'Classic Acetate',
#   'subCollectionId': 24103,
#   'relatedItems': [],
#   'isCygnusEnabled': False,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Transparent Blue Full Rim Rectangle Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Rectangle',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Transparent Blue Full Rim Rectangle',
#   'Model No.': 'VC E13037',
#   'Frame Size': 'Medium',
#   'Frame Width': '136 mm',
#   'Frame Dimensions': '52-19-140',
#   'Frame colour': 'Transparent Blue',
#   'Weight': '24 gm',
#   'Weight Group': 'Average',
#   'Material': 'Cellulose Acetate',
#   'Frame Material': 'Cellulose Acetate',
#   'Temple Material': 'Cellulose Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'Classic Acetate',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '39 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Transparent'},
#  {'id': '208951',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/peyush-bansal-shark-tank-navy-full-rim-wayfarer_csvfile-1705501799329-208951-desk.png',
#   'image_url_suffix': '/l/i/peyush-bansal-shark-tank-navy-full-rim-wayfarer_csvfile-1705501799329-208951-desk.png',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-hustlr-la-e15417-c15-eyeglasses.html',
#   'color': 'Navy',
#   'occasion': '',
#   'size': 'Medium',
#   'width': '139 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'model_name': 'LA E15417-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Navy',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 21568,
#   'avgRating': 4.6,
#   'totalNoOfRatings': '289',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/208951/android/sku_208951.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/208951/ios/sku_208951.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/208951/orignal/sku_208951.glb',
#   'qty': 11912,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/208951_bubble.png',
#   'subCollection': 'Lenskart Hustlr',
#   'subCollectionId': 26161,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Navy Full Rim Wayfarer Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Navy Full Rim Wayfarer',
#   'Model No.': 'LA E15417-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '49-21-150',
#   'Frame Dimensions With Height': '',
#   'Suited For': '',
#   'Frame colour': 'Navy',
#   'Glass Color': '',
#   'Weight': '17 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90 (Flexible Light-Weight)',
#   'Frame Material': 'TR90',
#   'Temple Material': 'TR90',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Air Essentials',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '43 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Navy',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '217202',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/lenskart-hustlr-lh-e16985-w-c2-eyeglasses_img_2274_18_jan24.jpg',
#   'image_url_suffix': '/l/i/lenskart-hustlr-lh-e16985-w-c2-eyeglasses_img_2274_18_jan24.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-hustlr-lh-e16985-w-c2-eyeglasses.html',
#   'color': 'Green',
#   'size': 'Medium',
#   'width': '139 mm',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'model_name': 'LH E16985-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Hustlr ACE-Olive',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': False,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 2291,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/217202/android/sku_217202.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/217202/ios/sku_217202.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/217202/orignal/sku_217202.glb',
#   'qty': 2220,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/217202_bubble.png',
#   'subCollection': 'Hustlr ACE',
#   'subCollectionId': 27732,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Olive Full Rim Wayfarer',
#   'Model No.': 'LH E16985-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '50-20-145',
#   'Frame Dimensions With Height': '',
#   'Frame colour': 'Olive',
#   'Glass Color': '',
#   'Weight': '24 gm',
#   'Weight Group': 'Average',
#   'Material': 'Acetate',
#   'Frame Material': 'Acetate',
#   'Temple Material': 'Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Lenskart HUSTLR',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '43 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Olive'},
#  {'id': '215389',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/light-green-transparent-multicolour-full-rim-geometric-vincent-chase-classic-acetate-vc-e16665-c2-eyeglasses_img_2086_19_jan24.jpg',
#   'image_url_suffix': '/v/i/light-green-transparent-multicolour-full-rim-geometric-vincent-chase-classic-acetate-vc-e16665-c2-eyeglasses_img_2086_19_jan24.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-e16665-c2-eyeglasses.html',
#   'color': 'Green',
#   'size': 'Medium',
#   'width': '137 mm',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'model_name': 'VC E16665',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'In Bloom',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 684,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Geometric', 'id': 24178, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/215389/android/sku_215389.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/215389/ios/sku_215389.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/215389/orignal/sku_215389.glb',
#   'qty': 1096,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/215389_bubble.png',
#   'subCollection': 'In Bloom',
#   'subCollectionId': 27752,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Geometric',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Light Green Transparent Full Rim Geometric',
#   'Model No.': 'VC E16665',
#   'Frame Size': 'Medium',
#   'Frame Width': '137 mm',
#   'Frame Dimensions': '55-16-140',
#   'Frame colour': 'Light Green Transparent',
#   'Weight': '21 gm',
#   'Weight Group': 'Average',
#   'Material': 'Acetate',
#   'Frame Material': 'Acetate',
#   'Temple Material': 'Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'Classic Acetate',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '43 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Multicolour'},
#  {'id': '217201',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/lenskart-hustlr-lh-e16985-w-c1-eyeglasses_img_2295_18_jan24.jpg',
#   'image_url_suffix': '/l/i/lenskart-hustlr-lh-e16985-w-c1-eyeglasses_img_2295_18_jan24.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-hustlr-lh-e16985-w-c1-eyeglasses.html',
#   'color': 'Blue',
#   'size': 'Medium',
#   'width': '139 mm',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'model_name': 'LH E16985-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Hustlr ACE-Denim',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': False,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 2581,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/217201/android/sku_217201.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/217201/ios/sku_217201.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/217201/orignal/sku_217201.glb',
#   'qty': 1741,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/217201_bubble.png',
#   'subCollection': 'Hustlr ACE',
#   'subCollectionId': 27732,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Denim Full Rim Wayfarer',
#   'Model No.': 'LH E16985-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '50-20-145',
#   'Frame Dimensions With Height': '',
#   'Frame colour': 'Denim',
#   'Glass Color': '',
#   'Weight': '24 gm',
#   'Weight Group': 'Average',
#   'Material': 'Acetate',
#   'Frame Material': 'Acetate',
#   'Temple Material': 'Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Lenskart HUSTLR',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '43 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Denim'},
#  {'id': '149607',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/vincent-chase-vc-e14211-c1-eyeglasses_vincent-chase-vc-e14211-c1-eyeglasses_G_5690.jpg',
#   'image_url_suffix': '/v/i/vincent-chase-vc-e14211-c1-eyeglasses_vincent-chase-vc-e14211-c1-eyeglasses_G_5690.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-e14211-c1-eyeglasses.html',
#   'color': 'Black',
#   'size': 'Medium',
#   'width': '137 mm',
#   'suited_for': '',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/VC-H.jpg',
#   'model_name': 'VC E14211',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Sleek Steel',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 8286,
#   'purchaseCount': 17898,
#   'avgRating': 4.7,
#   'totalNoOfRatings': '62',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Aviator', 'id': 11348, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/149607/android/sku_149607.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/149607/ios/sku_149607.scn',
#   'arModelMsiteAndDesktopUrl': '',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/149607/orignal/sku_149607.glb',
#   'qty': 219,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/149607_bubble.png',
#   'subCollection': 'SLEEK STEEL',
#   'subCollectionId': 25036,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Black Gunmetal Full Rim Aviator Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Aviator',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Black Gunmetal Full Rim Aviator',
#   'Model No.': 'VC E14211',
#   'Frame Size': 'Medium',
#   'Frame Width': '137 mm',
#   'Frame Dimensions': '53-17-145',
#   'Suited For': '',
#   'Frame colour': 'Black Gunmetal',
#   'Weight': '18 gm',
#   'Weight Group': 'Light',
#   'Material': 'Stainless Steel',
#   'Frame Material': 'Stainless Steel',
#   'Temple Material': 'Stainless Steel',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'SLEEK STEEL',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '45 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Black',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '217431',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/peyush-bansal-shark-tank-electric-green-full-rim-wayfarer_csvfile-1706676632735-217431_(2).jpg',
#   'image_url_suffix': '/l/i/peyush-bansal-shark-tank-electric-green-full-rim-wayfarer_csvfile-1706676632735-217431_(2).jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e15417-wc4-eyeglasses.html',
#   'color': 'Green',
#   'occasion': '',
#   'size': 'Medium',
#   'width': '139 mm',
#   'suited_for': '',
#   'brand_name': 'Lenskart Hustlr',
#   'brand_name_en': 'Lenskart Hustlr',
#   'model_name': 'LA E15417-W',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Electric Green',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': False,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 1628,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Wayfarer', 'id': 11343, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Hustlr', 'id': 26031, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/217431/android/sku_217431.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/217431/ios/sku_217431.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/217431/orignal/sku_217431.glb',
#   'qty': 1846,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/217431_bubble.png',
#   'subCollection': 'Lenskart Hustlr',
#   'subCollectionId': 26161,
#   'inclusiveText': '',
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Lenskart Air LA E15417-W C4 Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'Lenskart Hustlr',
#   'frametype_id': 'Full Rim',
#   'productName': 'Electric Green Full Rim Wayfarer',
#   'Model No.': 'LA E15417-W',
#   'Frame Size': 'Medium',
#   'Frame Width': '139 mm',
#   'Frame Dimensions': '50-20-150',
#   'Frame Dimensions With Height': '',
#   'Suited For': '',
#   'Frame colour': 'Electric Green',
#   'Glass Color': '',
#   'Weight': '21 gm',
#   'Weight Group': 'Average',
#   'Material': 'TR90',
#   'Frame Material': 'TR90',
#   'Temple Material': 'TR90',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Light-Weight',
#   'Collection': 'Lenskart HUSTLR',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '44 mm',
#   'Video': '',
#   'Condition': 'New',
#   'Lens Technology': '',
#   'Temple Colour': 'Electric Green',
#   'Power': '',
#   'And (For showing Attributes on Front End)': ''},
#  {'id': '209750',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/brown-transparent-full-rim-rectangle-lenskart-air-essentials-la-e15844-c4-eyeglasses_g_0280_25_05_2023.jpg',
#   'image_url_suffix': '/l/i/brown-transparent-full-rim-rectangle-lenskart-air-essentials-la-e15844-c4-eyeglasses_g_0280_25_05_2023.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e15844-c4-eyeglasses.html',
#   'color': 'Brown',
#   'size': 'Wide',
#   'width': '138 mm',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'model_name': 'LA E15844',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Matte Essentials',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 7401,
#   'avgRating': 5.0,
#   'totalNoOfRatings': '1',
#   'hashtagList': [{'name': 'Wide', 'id': 24069, 'property': 'frame_size_id'},
#    {'name': 'Rectangle', 'id': 11345, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/209750/android/sku_209750.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/209750/ios/sku_209750.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/209750/orignal/sku_209750.glb',
#   'qty': 2123,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/209750_bubble.png',
#   'subCollection': 'Matte Essential',
#   'subCollectionId': 26751,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Brown Transparent Full Rim Rectangle Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Wide',
#   'frame_shape_id': 'Rectangle',
#   'brandname_id': 'Lenskart Air',
#   'frametype_id': 'Full Rim',
#   'productName': 'Brown Transparent Full Rim Rectangle',
#   'Model No.': 'LA E15844',
#   'Frame Size': 'Wide',
#   'Frame Width': '138 mm',
#   'Frame Dimensions': '52-19-140',
#   'Frame colour': 'Brown Transparent',
#   'Weight': '19 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90',
#   'Frame Material': 'TR90',
#   'Temple Material': 'TR90',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Air Essentials',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '42 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Brown Transparent'},
#  {'id': '137975',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/sky-blue-full-rim-square-lenskart-air-fusion-la-e13069-c2-eyeglasses_lenskart-air-la-e13033-c2-eyeglasses_eyeglasses_g_3588_1_05_july23.jpg',
#   'image_url_suffix': '/l/i/sky-blue-full-rim-square-lenskart-air-fusion-la-e13069-c2-eyeglasses_lenskart-air-la-e13033-c2-eyeglasses_eyeglasses_g_3588_1_05_july23.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e13033-c2-eyeglasses.html',
#   'color': 'Blue',
#   'size': 'Medium',
#   'width': '135 mm',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/air-logo-Hi.jpg',
#   'model_name': 'LA E13069',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Air Fusion',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 10980,
#   'purchaseCount': 79742,
#   'avgRating': 4.6,
#   'totalNoOfRatings': '595',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Square', 'id': 19404, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/137975/android/sku_137975.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/137975/ios/sku_137975.scn',
#   'arModelMsiteAndDesktopUrl': 'NULL',
# ...
#   'qty': 2822,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/137920_bubble.png',
#   'subCollection': 'JJ Tints',
#   'subCollectionId': 26651,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Black Wayfarer Full Rim Sunglasses',
#   'prescriptionType': [],
#   'Market Price': 5000,
#   'Lenskart Price': 5000,
#   'frame_size_id': 'Wide',
#   'frame_shape_id': 'Wayfarer',
#   'brandname_id': 'John Jacobs',
#   'frametype_id': 'Full Rim',
#   'productName': 'Black Full Rim Wayfarer',
#   'Model No.': 'JJ S13025',
#   'Frame Size': 'Wide',
#   'Frame Width': '140 mm',
#   'Frame Dimensions': '52-18-145',
#   'Frame colour': 'Black',
#   'Glass Color': 'Grey',
#   'Weight': '24 gm',
#   'Weight Group': 'Light',
#   'Material': 'Italian Acetate',
#   'Frame Material': 'Italian Acetate',
#   'Temple Material': 'Italian Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Collection': 'JJ Tints',
#   'Lens Material': 'Polycarbonate',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '42 mm',
#   'Condition': 'New',
#   'Lens Technology': 'Polarized and 100% UV Protection (UV 400)',
#   'Temple Colour': 'Black'},
#  {'id': '209224',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/vincent-chase-vc-e11801-c13-eyeglasses_g_2577_20_06_2023.jpg',
#   'image_url_suffix': '/v/i/vincent-chase-vc-e11801-c13-eyeglasses_g_2577_20_06_2023.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-e11801-c13-eyeglasses.html',
#   'color': 'Black',
#   'size': 'Narrow',
#   'width': '130 mm',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'model_name': 'VC E11801',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'High Density Acetate',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': False,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 12250,
#   'avgRating': 5.0,
#   'totalNoOfRatings': '1',
#   'hashtagList': [{'name': 'Narrow', 'id': 24070, 'property': 'frame_size_id'},
#    {'name': 'Rectangle', 'id': 11345, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'qty': 6589,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/209224_bubble.png',
#   'subCollection': 'HD Acetate',
#   'subCollectionId': 25042,
#   'relatedItems': [],
#   'isCygnusEnabled': False,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Black Full Rim Rectangle Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Narrow',
#   'frame_shape_id': 'Rectangle',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Black Full Rim Rectangle',
#   'Model No.': 'VC E11801',
#   'Frame Size': 'Narrow',
#   'Frame Width': '130 mm',
#   'Frame Dimensions': '50-14-145',
#   'Frame colour': 'Black',
#   'Weight': '21 gm',
#   'Weight Group': 'Average',
#   'Material': 'High Density Acetate',
#   'Frame Material': 'High Density Acetate',
#   'Temple Material': 'High Density Acetate',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'HD Acetate',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '37 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Black'},
#  {'id': '151377',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/Silver-Maroon-Full-Rim-Geometric-Vincent-Chase-LIVEWIRE-VC-S14506-C5-Polarized-Sunglasses_G_7230.jpg',
#   'image_url_suffix': '/v/i/Silver-Maroon-Full-Rim-Geometric-Vincent-Chase-LIVEWIRE-VC-S14506-C5-Polarized-Sunglasses_G_7230.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-s14506-c5-sunglasses.html',
#   'color': 'Gunmetal',
#   'occasion': 'Vacation',
#   'size': 'Medium',
#   'width': '140 mm',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'brand_logo': '',
#   'model_name': 'VC S14506',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 2000},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 2000}],
#   'is_tbyb': False,
#   'tags': 'Livewire',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'sunglasses',
#   'specifications': [],
#   'wishlistCount': 1674,
#   'purchaseCount': 26542,
#   'avgRating': 4.6,
#   'totalNoOfRatings': '17',
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Geometric', 'id': 24178, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCSUN',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/151377/android/sku_151377.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/151377/ios/sku_151377.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/151377/orignal/sku_151377.glb',
#   'qty': 1222,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/151377_bubble.png',
#   'subCollection': 'Livewire',
#   'subCollectionId': 25021,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Silver Geometric Full Rim Sunglasses',
#   'prescriptionType': [],
#   'Market Price': 2000,
#   'Lenskart Price': 2000,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Geometric',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Silver Full Rim Geometric',
#   'Model No.': 'VC S14506',
#   'Frame Size': 'Medium',
#   'Frame Width': '140 mm',
#   'Frame Dimensions': '56-17-145',
#   'Frame colour': 'Silver',
#   'Glass Color': 'Green',
#   'Weight': '21.2 gm',
#   'Material': 'Stainless Steel',
#   'Frame Material': 'Stainless Steel',
#   'Temple Material': 'Stainless Steel',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Collection': 'LIVEWIRE',
#   'Lens Material': 'Polycarbonate',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '47 mm',
#   'Condition': 'New',
#   'Lens Technology': '100% UV Protection (UV 400)',
#   'Temple Colour': 'Silver Maroon'},
#  {'id': '151529',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/blue-transparent-full-rim-rectangle-lenskart-air-classic-la-e14529-c3-eyeglasses_g_9379.jpg',
#   'image_url_suffix': '/l/i/blue-transparent-full-rim-rectangle-lenskart-air-classic-la-e14529-c3-eyeglasses_g_9379.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e14529-c3-eyeglasses.html',
#   'color': 'Blue',
#   'size': 'Wide',
#   'width': '140 mm',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/air-logo-Hi.jpg',
#   'model_name': 'LA E14529',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Pro Grip',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 105,
#   'purchaseCount': 28097,
#   'avgRating': 4.85,
#   'totalNoOfRatings': '27',
#   'hashtagList': [{'name': 'Wide', 'id': 24069, 'property': 'frame_size_id'},
#    {'name': 'Rectangle', 'id': 11345, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://3d-asset-lookr-new.s3.ap-southeast-1.amazonaws.com/frameassets/151529/android/sku_151529.glb',
#   'arModelIOSUrl': 'https://3d-asset-lookr-new.s3.ap-southeast-1.amazonaws.com/frameassets/151529/ios/sku_151529.scn',
#   'arModelOriginalUrl': 'https://3d-asset-lookr-new.s3.ap-southeast-1.amazonaws.com/frameassets/151529/orignal/sku_151529.glb',
#   'qty': 2512,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/151529_bubble.png',
#   'subCollection': 'Pro Grip',
#   'subCollectionId': 25017,
#   'relatedItems': [],
#   'isCygnusEnabled': False,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Blue Transparent Full Rim Rectangle Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Wide',
#   'frame_shape_id': 'Rectangle',
#   'brandname_id': 'Lenskart Air',
#   'frametype_id': 'Full Rim',
#   'productName': 'Blue Transparent Full Rim Rectangle',
#   'Model No.': 'LA E14529',
#   'Frame Size': 'Wide',
#   'Frame Width': '140 mm',
#   'Frame Dimensions': '52-17-145',
#   'Frame colour': 'Blue Transparent',
#   'Weight': '13.8 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90 (Flexible Light-Weight)',
#   'Frame Material': 'Ultem',
#   'Temple Material': 'Ultem',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Standard',
#   'Collection': 'Air Flex',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '35 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Blue'},
#  {'id': '149022',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//l/i/pink-transparent-full-rim-cat-eye-lenskart-air-fusion-la-e14101-c2-eyeglasses_lenskart-air-la-e14101-c2-c2-eyeglasses_g_7524_28july23.jpg',
#   'image_url_suffix': '/l/i/pink-transparent-full-rim-cat-eye-lenskart-air-fusion-la-e14101-c2-eyeglasses_lenskart-air-la-e14101-c2-c2-eyeglasses_g_7524_28july23.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/lenskart-air-la-e14101-c2-c2-eyeglasses.html',
#   'color': 'Pink',
#   'size': 'Wide',
#   'width': '138 mm',
#   'brand_name': 'Lenskart Air',
#   'brand_name_en': 'Lenskart Air',
#   'brand_logo': 'https://static.lenskart.com/media/wysiwyg/blanco/images/air-logo-Hi.jpg',
#   'model_name': 'LA E14101',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Float Pop',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': True,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 1740,
#   'purchaseCount': 19647,
#   'avgRating': 4.75,
#   'totalNoOfRatings': '35',
#   'hashtagList': [{'name': 'Wide', 'id': 24069, 'property': 'frame_size_id'},
#    {'name': 'Cat Eye', 'id': 11351, 'property': 'frame_shape_id'},
#    {'name': 'Lenskart Air', 'id': 22563, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/149022/android/sku_149022.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/149022/ios/sku_149022.scn',
#   'arModelMsiteAndDesktopUrl': '',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/149022/orignal/sku_149022.glb',
#   'qty': 2064,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/149022_bubble.png',
#   'subCollection': 'Float Pop',
#   'subCollectionId': 25009,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'searchProductName': 'Pink Transparent Full Rim Cat Eye Eyeglasses',
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Wide',
#   'frame_shape_id': 'Cat Eye',
#   'brandname_id': 'Lenskart Air',
#   'frametype_id': 'Full Rim',
#   'productName': 'Pink Transparent Full Rim Cat Eye',
#   'Model No.': 'LA E14101',
#   'Frame Size': 'Wide',
#   'Frame Width': '138 mm',
#   'Frame Dimensions': '52-18-145',
#   'Frame colour': 'Pink Transparent',
#   'Weight': '17 gm',
#   'Weight Group': 'Light',
#   'Material': 'TR90 & Stainless Steel',
#   'Frame Material': 'TR90',
#   'Temple Material': 'Stainless Steel',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Light-Weight',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'Air Fusion',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Women',
#   'Height': '42 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Pink Transparent'},
#  {'id': '215775',
#   'image_url': 'https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/vincent-chase-vc-e16699-c1-eyeglasses_img_9064_04_01_2024.jpg',
#   'image_url_suffix': '/v/i/vincent-chase-vc-e16699-c1-eyeglasses_img_9064_04_01_2024.jpg',
#   'imageUrls': [],
#   'product_url': 'https://www.lenskart.com/vincent-chase-vc-e16699-c1-eyeglasses.html',
#   'color': 'Blue',
#   'size': 'Medium',
#   'width': '135 mm',
#   'brand_name': 'Vincent Chase',
#   'brand_name_en': 'Vincent Chase',
#   'model_name': 'VC E16699',
#   'prices': [{'name': 'Market Price', 'currency_code': 'INR', 'price': 1700},
#    {'name': 'Lenskart Price', 'currency_code': 'INR', 'price': 1700}],
#   'is_tbyb': False,
#   'tags': 'Patriot',
#   'color_options': [],
#   'totalColorAvailable': 0,
#   'is_ditto': False,
#   'classification': 'eyeframe',
#   'specifications': [],
#   'wishlistCount': 0,
#   'purchaseCount': 1674,
#   'avgRating': 0.0,
#   'hashtagList': [{'name': 'Medium', 'id': 11341, 'property': 'frame_size_id'},
#    {'name': 'Round', 'id': 11346, 'property': 'frame_shape_id'},
#    {'name': 'Vincent Chase', 'id': 10733, 'property': 'brandname_id'},
#    {'name': 'Full Rim', 'id': 11370, 'property': 'frametype_id'}],
#   'offerName': 'VCEYE',
#   'cmsLinkAndroid': 'https://www.lenskart.com/cms-frame-size',
#   'cmsLinkIos': 'https://www.lenskart.com/cms-frame-size-ios',
#   'arModelAndroidUrl': 'https://lookr-static.lenskart.com/frameassets/215775/android/sku_215775.glb',
#   'arModelIOSUrl': 'https://lookr-static.lenskart.com/frameassets/215775/ios/sku_215775.scn',
#   'arModelOriginalUrl': 'https://lookr-static.lenskart.com/frameassets/215775/orignal/sku_215775.glb',
#   'qty': 764,
#   'frameColorImage': 'https://ds-static.lenskart.com/product_color_bubble_images/215775_bubble.png',
#   'subCollection': 'Patriot',
#   'subCollectionId': 26582,
#   'relatedItems': [],
#   'isCygnusEnabled': True,
#   'isCashbackApplicable': False,
#   'prescriptionType': [],
#   'Market Price': 1700,
#   'Lenskart Price': 1700,
#   'frame_size_id': 'Medium',
#   'frame_shape_id': 'Round',
#   'brandname_id': 'Vincent Chase',
#   'frametype_id': 'Full Rim',
#   'productName': 'Blue Full Rim Round',
#   'Model No.': 'VC E16699',
#   'Frame Size': 'Medium',
#   'Frame Width': '135 mm',
#   'Frame Dimensions': '50-20-140',
#   'Frame colour': 'Blue',
#   'Weight': '23 gm',
#   'Weight Group': 'Average',
#   'Material': 'Stainless Steel',
#   'Frame Material': 'Stainless Steel',
#   'Temple Material': 'Stainless Steel',
#   'Prescription Type': 'Bifocal / Progressive',
#   'Frame Style': 'Standard',
#   'Frame Style Secondary': 'Youth',
#   'Collection': 'SLEEK STEEL',
#   'Product Warranty': '1 Year Manufacturer Warranty',
#   'Gender': 'Unisex',
#   'Height': '47 mm',
#   'Condition': 'New',
#   'Temple Colour': 'Blue'}]

# %%
df = pandas.DataFrame(df_list)

eyeglasses_csv_path = './csvs/eyeglasses.csv'
df.to_csv(eyeglasses_csv_path)
logging.info(f"Product details of eyeglasses converted to data frame and csv - {eyeglasses_csv_path}")
